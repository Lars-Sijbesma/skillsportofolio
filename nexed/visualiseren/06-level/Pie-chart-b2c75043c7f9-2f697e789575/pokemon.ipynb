# %% [markdown]
# # FUCK
# Meep.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# bleh

# %%
df = pd.read_csv('pokemon_extended.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %% [markdown]
# meep

# %%
gen = df.query("generation == 1")
sns.lineplot(data=df, x="generation", y="weight_kg")
# Out:
# <Axes: xlabel='generation', ylabel='weight_kg'>

# %% [markdown]
# kys

# %%
gen = df.query("generation == 1")
sns.lineplot(data=df, x="generation", y="height_m")
# Out:
# <Axes: xlabel='generation', ylabel='height_m'>

# %% [markdown]
# Fuck you

# %%
# First, get the type counts from your DataFrame
type_counts = df["type1"].value_counts()

# Then create the DataFrame
type_counts_df = type_counts.reset_index()
type_counts_df.columns = ["type1", "Aantal Pokémon"]
print(type_counts_df)
# Out:
#        type1  Aantal Pokémon
# 0      water             114
# 1     normal             105
# 2      grass              78
# 3        bug              72
# 4    psychic              53
# 5       fire              52
# 6       rock              45
# 7   electric              39
# 8     poison              32
# 9     ground              32
# 10      dark              29
# 11  fighting              28
# 12    dragon              27
# 13     ghost              27
# 14     steel              24
# 15       ice              23
# 16     fairy              18
# 17    flying               3

# %% [markdown]
# Meep

# %%
sizes = [114, 105, 78, 72, 53, 52, 45, 39, 32, 32, 29, 28, 27, 27, 24, 23, 18, 3]
colors = ['gold', 'lightskyblue', 'lightcoral', 'lightgreen, red, aqua, blue,']

# Creating a custom colored pie chart
# plt.pie(sizes, labels=['water', 'normal', 'grass', 'bug, psychic, fire, rock, electric, poison, ground, dark, fighting, dragon, ghost, steel, ice, fairy, flying'], colors=colors)

# plt.pie(type_counts.count, labels=type_counts, colors=colors)

type_counts.plot.pie()

plt.title('Pokemon')
plt.show()

# %%
type (type_counts)
# Out:
# pandas.core.series.Series
