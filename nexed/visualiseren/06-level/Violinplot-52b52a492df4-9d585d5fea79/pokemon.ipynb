# %% [markdown]
# # Ballin
# Jort.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Leedeleedle leedel

# %%
df = pd.read_csv('pokemon_small.csv')

df
# Out:
#      Unnamed: 0        Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0             1   Bulbasaur    Grass  Poison    318   45      49       49
# 1             2     Ivysaur    Grass  Poison    405   60      62       63
# 2             3    Venusaur    Grass  Poison    525   80      82       83
# 3             4  Charmander     Fire     NaN    309   39      52       43
# 4             5  Charmeleon     Fire     NaN    405   58      64       58
# ..          ...         ...      ...     ...    ...  ...     ...      ...
# 146         147     Dratini   Dragon     NaN    300   41      64       45
# 147         148   Dragonair   Dragon     NaN    420   61      84       65
# 148         149   Dragonite   Dragon  Flying    600   91     134       95
# 149         150      Mewtwo  Psychic     NaN    680  106     110       90
# 150         151         Mew  Psychic     NaN    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Stage  Legendary
# ...

# %% [markdown]
# bleh

# %%
sns.histplot(data=df, x="HP")
# Out:
# <Axes: xlabel='HP', ylabel='Count'>

# %% [markdown]
# Hahahahahaha

# %%
sns.histplot(data=df, x="HP", bins=35)
# Out:
# <Axes: xlabel='HP', ylabel='Count'>

# %% [markdown]
# Nee geen zin om te vergelijken

# %%
sns.scatterplot(data=df, x="Attack", y="HP")
# Out:
# <Axes: xlabel='Attack', ylabel='HP'>

# %% [markdown]
# Pluh

# %%
sns.scatterplot(data=df, x="Attack", y="Speed")
# Out:
# <Axes: xlabel='Attack', ylabel='Speed'>

# %% [markdown]
# Bleh

# %%
sns.scatterplot(data=df, x="Attack", y="HP", hue="Type 1")
# Out:
# <Axes: xlabel='Attack', ylabel='HP'>

# %% [markdown]
# nee

# %%
sns.scatterplot(data=df, x="Attack", y="HP", hue="Type 1", style="Type 1")
# Out:
# <Axes: xlabel='Attack', ylabel='HP'>

# %% [markdown]
# K, y also S

# %%
sns.boxplot(data=df, x="Stage", y="Total")
# Out:
# <Axes: xlabel='Stage', ylabel='Total'>

# %% [markdown]
# not going to explain it cause fuck you

# %% [markdown]
# Nah

# %%
# Full dataset (no filtering)
sns.boxplot(data=df, x="Stage", y="Total", hue="Legendary")

plt.show()

# %% [markdown]
# bleh

# %%
# Stap 1: Filter op Type 1
ft = ["Water", "Grass", "Fire", "Bug"]

# Stap 2: Maak een nieuw DataFrame met alleen de gewenste types en géén Stage 3 Pokémon
ft_df = df[
    (df["Type 1"].isin(ft)) &
    (df["Stage"] != 3)
]

# Optioneel: Bekijk het resultaat
print(ft_df.head())
# Out:
#    Unnamed: 0        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0           1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1           2     Ivysaur  Grass  Poison    405  60      62       63       80
# 3           4  Charmander   Fire     NaN    309  39      52       43       60
# 4           5  Charmeleon   Fire     NaN    405  58      64       58       80
# 6           7    Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Stage  Legendary
# 0       65     45      1      False
# 1       80     60      2      False
# 3       50     65      1      False
# 4       65     80      2      False
# 6       64     43      1      False

# %% [markdown]
# la

# %%
sns.violinplot(data=ft_df, y="Total", x="Type 1")
# Out:
# <Axes: xlabel='Type 1', ylabel='Total'>

# %% [markdown]
# lalala

# %%
sns.violinplot(data=ft_df, x="Type 1", y="Total", hue="Type 1", split=True, inner="quart")
# Out:
# <Axes: xlabel='Type 1', ylabel='Total'>

# %% [markdown]
# nah

# %%
sns.violinplot(data=ft_df, x="Type 1", y="Total", hue="Type 1", split=True, inner="quart", cut=0)
sns.swarmplot(data=ft_df, x='Type 1', y='Total', hue='Stage', dodge=True, palette=['black'])
# Out:
# C:\Users\didig\AppData\Local\Temp\ipykernel_5100\2010623807.py:2: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.swarmplot(data=ft_df, x='Type 1', y='Total', hue='Stage', dodge=True, palette=['black'])
# <Axes: xlabel='Type 1', ylabel='Total'>

# %% [markdown]
# er zijn te weinig values
