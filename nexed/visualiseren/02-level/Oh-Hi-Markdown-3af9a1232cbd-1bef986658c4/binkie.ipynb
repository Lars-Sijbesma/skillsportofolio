# %% [markdown]
# <h1>Coolste document ter wereld</h1>
# <p>Hallo, mijn naam is <strong>Binkie de beer</strong> en ik houd van eten! Mijn favorieten gerechten zijn: </p>
# <ul>
# <li> Gebakken vis;</li>
# <li> gebraden vis;</li>
# <li>Gepofte vis met <em>veel</em> pindasaus;</li>
# </ul>
# <br>
# <h1>Wat ik hier doe</h1>
# <p>Ik ben een programmeur! Dit doe ik voornamelijk omdat ik intelligent ben. Kijk maar!</p>
# <ol>
# <li> Ik kan python programmeren</li>
# <li> Ikkan HTML schrijven</li>
# <li> Ik kan Markdown schrijven</li>
# <li> Ik kan vier dingen opsommen!</li>
# </ol>
# <br>
# <p> Ik ben de intelligenste beer die je ooit in je leven zult tegenkomen! Geloof je mij niet? <a href="https://www.google.com/">Google het maar</a>, dan zul je het zelf zien! </p>

# %%
print("Wauw!")
# Out:
# Wauw!
